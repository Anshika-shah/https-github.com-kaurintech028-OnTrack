# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv("E:/2nd yr/project ontrack/uber-raw-data-apr14.csv.zip")

# %%
data
# Out:
#                  Date/Time      Lat      Lon    Base
# 0         4/1/2014 0:11:00  40.7690 -73.9549  B02512
# 1         4/1/2014 0:17:00  40.7267 -74.0345  B02512
# 2         4/1/2014 0:21:00  40.7316 -73.9873  B02512
# 3         4/1/2014 0:28:00  40.7588 -73.9776  B02512
# 4         4/1/2014 0:33:00  40.7594 -73.9722  B02512
# ...                    ...      ...      ...     ...
# 564511  4/30/2014 23:22:00  40.7640 -73.9744  B02764
# 564512  4/30/2014 23:26:00  40.7629 -73.9672  B02764
# 564513  4/30/2014 23:31:00  40.7443 -73.9889  B02764
# 564514  4/30/2014 23:32:00  40.6756 -73.9405  B02764
# 564515  4/30/2014 23:48:00  40.6880 -73.9608  B02764
#
# [564516 rows x 4 columns]

# %%
data["Date/Time"]=data["Date/Time"].map(pd.to_datetime)
data
# Out:
#                  Date/Time      Lat      Lon    Base  day  weekdays  hour
# 0      2014-04-01 00:11:00  40.7690 -73.9549  B02512    1         1     0
# 1      2014-04-01 00:17:00  40.7267 -74.0345  B02512    1         1     0
# 2      2014-04-01 00:21:00  40.7316 -73.9873  B02512    1         1     0
# 3      2014-04-01 00:28:00  40.7588 -73.9776  B02512    1         1     0
# 4      2014-04-01 00:33:00  40.7594 -73.9722  B02512    1         1     0
# ...                    ...      ...      ...     ...  ...       ...   ...
# 564511 2014-04-30 23:22:00  40.7640 -73.9744  B02764   30         2    23
# 564512 2014-04-30 23:26:00  40.7629 -73.9672  B02764   30         2    23
# 564513 2014-04-30 23:31:00  40.7443 -73.9889  B02764   30         2    23
# 564514 2014-04-30 23:32:00  40.6756 -73.9405  B02764   30         2    23
# 564515 2014-04-30 23:48:00  40.6880 -73.9608  B02764   30         2    23
#
# [564516 rows x 7 columns]

# %%
data["day"]=data["Date/Time"].apply(lambda x: x.day)
data["weekdays"]=data["Date/Time"].apply(lambda x: x.weekday())
data["hour"]=data["Date/Time"].apply(lambda x: x.hour)

# %%
data
# Out:
#                  Date/Time      Lat      Lon    Base  day  weekdays  hour
# 0      2014-04-01 00:11:00  40.7690 -73.9549  B02512    1         1     0
# 1      2014-04-01 00:17:00  40.7267 -74.0345  B02512    1         1     0
# 2      2014-04-01 00:21:00  40.7316 -73.9873  B02512    1         1     0
# 3      2014-04-01 00:28:00  40.7588 -73.9776  B02512    1         1     0
# 4      2014-04-01 00:33:00  40.7594 -73.9722  B02512    1         1     0
# ...                    ...      ...      ...     ...  ...       ...   ...
# 564511 2014-04-30 23:22:00  40.7640 -73.9744  B02764   30         2    23
# 564512 2014-04-30 23:26:00  40.7629 -73.9672  B02764   30         2    23
# 564513 2014-04-30 23:31:00  40.7443 -73.9889  B02764   30         2    23
# 564514 2014-04-30 23:32:00  40.6756 -73.9405  B02764   30         2    23
# 564515 2014-04-30 23:48:00  40.6880 -73.9608  B02764   30         2    23
#
# [564516 rows x 7 columns]

# %%
sns.set(rc={'figure.figsize':(15,13)})
sns.distplot(data["day"])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_24024\1521816789.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["day"])
# <Axes: xlabel='day', ylabel='Density'>

# %%
sns.distplot(data["hour"])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_24024\3271431904.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["hour"])
# <Axes: xlabel='hour', ylabel='Density'>

# %%
sns.distplot(data["weekdays"])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_24024\3159460598.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["weekdays"])
# <Axes: xlabel='weekdays', ylabel='Density'>

# %%
df=data.groupby(["weekdays","hour"]).apply(lambda x: len(x))
df=df.unstack()
sns.heatmap(df,annot=False)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_24024\3270303052.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df=data.groupby(["weekdays","hour"]).apply(lambda x: len(x))
# <Axes: xlabel='hour', ylabel='weekdays'>

# %%
data.plot(kind='scatter',x='Lon', y='Lat', s=data['day'], label='Uber Trips', figsize=(12, 10))
# Out:
# <Axes: xlabel='Lon', ylabel='Lat'>
